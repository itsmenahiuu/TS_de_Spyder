# %% [markdown]
# # </u>TS0 Naudeau Nahiara</u>

# %% [markdown]
# ## Código

# %%
import numpy as np  
import matplotlib.pyplot as plt

def mi_funcion_sen( vmax, dc, ff, ph, nn, fs): 
#defino (def) mi funcion para pasarle todos los datos

#vmax:amplitud max de la senoidal [Volts]
#dc:valor medio [Volts]
#ff:frecuencia [Hz]
#ph:fase en [rad]
#nn:cantidad de muestras
#fs:frecuencia de muestreo [Hz]

    Ts = 1/fs #período de muestre (osea cuanto tiempo hay entre muestra y muestra)
    tt = np.linspace(0, (nn-1)*Ts, nn) #tt seria el vector de tiempos donde se evalúa la señal
#np.linspace(start, stop, num, endpoint=True, retstep=False, dtype=None, axis=0)

# - start: valor inicial
# - stop: valor final
# - num: cantidad de puntos (default = 50)
# - endpoint: True -> incluye el valor final; False -> no lo incluye
# - retstep: True -> devuelve tambien el paso entre puntos
# - dtype: tipo de dato (float, int, etc.)
# - axis: eje en el que se coloca el resultado en arrays multidimensionales
 
    xx=vmax*np.sin(2*np.pi*ff*tt+ph)+dc #np.pi es pi y np.sin es para hacer el seno

    return tt,xx #cierro mi funcion "def", es como las funciones de C pero no tiene llaves, es asi nomas
#se tabula todo lo que esta dentro de mi funcion 

N=1000
fs=1000
tt, yy = mi_funcion_sen(1, 0, 1, 0, N, fs)
plt.figure(1)
plt.plot(tt, yy, color='orchid') 
plt.title('Señal Senoidal')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bonus

# %%
#cambio mi ff por las del bonus
tt1, yy1 = mi_funcion_sen(1, 0, 500, 0, 1000, 1000)
tt2, yy2 = mi_funcion_sen(1, 0, 999, 0, 1000, 1000)
tt3, yy3 = mi_funcion_sen(1, 0, 1001, 0, 1000, 1000)
tt4, yy4 = mi_funcion_sen(1, 0, 2001, 0, 1000, 1000)

plt.figure(2)
plt.subplot(2,2,1) #como en matlab
plt.plot(tt1, yy1, color='pink') 
plt.title('ff = 500 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(tt2, yy2, color='deeppink') 
plt.title('ff = 999 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.subplot(2,2,3)
plt.plot(tt3, yy3, color='mediumorchid') 
plt.title('ff = 1001 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(tt4, yy4, color='rebeccapurple') 
plt.title('ff = 2001 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')

plt.grid(True)
plt.tight_layout()  #para que no se solapen mis graficos (solucion que me dio gtp a un error que tenia)
plt.show()

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Los gráficos muestran cómo la frecuencia de la señal afecta su representación muestreada.
# - Cuando la frecuencia de mi señal es menor a la mitad de la frecuencia de muestreo (cantidad de veces por segundo que se toma una muestra de una señal continua para convertirla en digital) la onda senoidal se ve correctamente. Esto demuestra que el muestreo cumple con el teorema de Nyquist, por lo que la señal puede ser reconstruida sin perder información.
#                           ***frecuencia de nyquist*** --> $\frac{f_s}{2}$
# - Cuando utilizo la frecuencia de Nyquist, teóricamente debería poder armar una senoidal (con 2 muestras --> $\frac{f_s}{f_f}$), pero realmente no se puede distinguir, lo que hace el código es poner mis dos muestras en donde la senoidal vale cero e intentar gracficar algo, dando como resultado un grafico nada parecido a una senoidal con valores del eje "y" muy cercanos a cero.
# Si yo quisiese ver los picos de la amplitud máxima, puedo defasar mi onda al sumar $\frac{\pi}{2}$
# - Cuando mi frecuencia esta por encima de nyquist se produce un solapamiento o *"aliasing"* donde mi muestreo ya no me puede armar mi senoidal y las replicas espectrales se solapan. Cuando estas se solapan nos queda una señal "invertida" con una frecuencia aparente donde:
# $$f_{aparente}=|f_s - f_{señal}|$$

# %% [markdown]
# ## Otras señales

# %% [markdown]
# Para probar que la señal aparente cumple con la formula previamente escrita, se puede armar una señal donde la frecuencia sea por ejemplo f=2002

# %%
tt5, yy5 = mi_funcion_sen(1, 0, 2, 0, N, fs)

plt.figure(3)
plt.subplot(1,2,1) 
plt.plot(tt5, yy5, color='orchid') 
plt.title('f = 2 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

tt6, yy6 = mi_funcion_sen(1, 0, 2002, 0, 1000, 1000)
plt.subplot(1,2,2) 
plt.plot(tt6, yy6, color='pink') 
plt.title('f = 2002 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %% [markdown]
# También podemos ver como a medida que nos acercamos a la frecuencia de nyquist, mi señal deja de parecerse a una senoidal:

# %%
tt5, yy5 = mi_funcion_sen(1, 0, 100, 0, N, fs)
tt6, yy6 = mi_funcion_sen(1, 0, 150, 0, 1000, 1000)

plt.figure(3)
plt.subplot(1,2,1) 
plt.plot(tt5, yy5, color='mediumorchid') 
plt.title('f = 100 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.subplot(1,2,2) 
plt.plot(tt6, yy6, color='rebeccapurple') 
plt.title('f = 150 Hz')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud [Volts]')
plt.grid(True)

plt.tight_layout()  
plt.show()

# %% [markdown]
# ## FeedBack

# %% [markdown]
# Relacionado a los temas vistos en clase no hubo muchos problemas, lo único que aun no cierra tanto es el porqué se invierte la señal.
# Respecto al uso de IA, tuve que usarla bastante para poder entender python ya que jamás lo había usado y no lograba que me compile el codigo o que haga lo que yo quiero, por lo que tuve que mandarle el codigo a chatgtp para que me corrija mis erroes de sintaxis.
